# %%
# !pip install graphdatascience

# %%
# Need to create user first

# Define connection details
uri = "bolt://localhost:7687"  # Replace with your Neo4j URI
username = "username"         # Replace with your Neo4j username
password = "password"      # Replace with your Neo4j password
db_name = "nutrition"          # Specify the database you want to work on

# %%
from graphdatascience import GraphDataScience
import pandas as pd

# Connecting with the Neo4j database using GDS library
# Need to add a user by using CREATE USER in Neo4j browser
gds = GraphDataScience(uri, auth=(username, password), database=db_name)

# Should do this one in the conf file:
# dbms.security.procedures.unrestricted=jwt.security.*,gds.*
# dbms.security.procedures.allowlist=apoc.coll.*,apoc.load.*,gds.*

# Check the installed GDS version on the server
print(gds.version())
assert gds.version()
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated field from a procedure. ('advertisedListenAddress' returned by 'gds.debug.arrow' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: 'CALL gds.debug.arrow()'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated field from a procedure. ('serverLocation' returned by 'gds.debug.arrow' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: 'CALL gds.debug.arrow()'
# 2.7.0

# %% [markdown]
# ### Formating Pandas display

# %%
# Set pandas display options to prevent truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Defining the Pipeline
#
# Here we are creating a pipeline with the name “pipe”. Each component that we add must be in the exact order that we want it to be inside the pipeline.

# %%
# When we run the cypher query using the GDS library, we get an output as a DataFrame. You can save it in a variable to inspect it further.

# Define the pipeline name
pipeline_name = 'pipe'

# Check if the pipeline already exists
existing_pipelines = gds.run_cypher("CALL gds.pipeline.list() YIELD pipelineName")

existing_pipelines
# Out:
# Empty DataFrame
# Columns: [pipelineName]
# Index: []

# %%
# Check if the pipeline exists and drop it if it does
if pipeline_name in existing_pipelines['pipelineName'].values:
    try:
        gds.run_cypher("CALL gds.pipeline.drop('pipe')")
        print("Existing pipeline dropped.")
    except Exception as e:
        print(f"Error dropping existing pipeline: {e}")

# Create the pipeline
result = gds.run_cypher(f"CALL gds.beta.pipeline.linkPrediction.create('{pipeline_name}')")
print("Pipeline created successfully.")
result
# Out:
# Pipeline created successfully.
#    name nodePropertySteps featureSteps  \
# 0  pipe                []           []
#
#                                                                                        splitConfig  \
# 0  {'testFraction': 0.1, 'validationFolds': 3, 'trainFraction': 0.1, 'negativeSamplingRatio': 1.0}
#
#     autoTuningConfig  \
# 0  {'maxTrials': 10}
#
#                                                                parameterSpace
# 0  {'MultilayerPerceptron': [], 'RandomForest': [], 'LogisticRegression': []}

# %% [markdown]
# ### Adding node properties
#
# In this code we adding the component which would calculate the node embeddings based on Fast Random Projection algorithm. The embedding vector would be of length 256, stored inside our projected graph under the property name “embedding”.

# %%
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.addNodeProperty('pipe', 'fastRP', {
  mutateProperty: 'embedding',
  embeddingDimension: 256,
  randomSeed: 42
})
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while adding node property: {e}")
    print()

result
# Out:
#    name  \
# 0  pipe
#
#                                                                                                                                                                   nodePropertySteps  \
# 0  [{'name': 'gds.fastRP.mutate', 'config': {'randomSeed': 42, 'mutateProperty': 'embedding', 'contextRelationshipTypes': [], 'embeddingDimension': 256, 'contextNodeLabels': []}}]
#
#   featureSteps  \
# 0           []
#
#                                                                                        splitConfig  \
# 0  {'testFraction': 0.1, 'validationFolds': 3, 'trainFraction': 0.1, 'negativeSamplingRatio': 1.0}
#
#     autoTuningConfig  \
# 0  {'maxTrials': 10}
#
#                                                                parameterSpace
# 0  {'MultilayerPerceptron': [], 'RandomForest': [], 'LogisticRegression': []}

# %% [markdown]
# ### Concatenating the node properties
# If we have any numerical property (like age, income, etc.) that we want to use alongside the node embeddings, we must define them here. We used HADAMARD transform here to concatenate the defined properties. Keep in mind that, as of now, GDS only supports numerical columns. If we want to use categorical columns, we should store the properties as a one-hot encoded vector and then add the name of that property here

# %%
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.addFeature('pipe', 'hadamard', {
  nodeProperties: ['embedding']
}) YIELD featureSteps
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while adding feature: {e}")
    print()

result
# Out:
#                                                           featureSteps
# 0  [{'name': 'HADAMARD', 'config': {'nodeProperties': ['embedding']}}]

# %% [markdown]
# ### Configuring the pipeline split
# Here I am splitting the data into training, testing splits to evaluate our model performance.

# %%
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.configureSplit('pipe', {
  testFraction: 0.25,
  trainFraction: 0.6,
  validationFolds: 3
})
YIELD splitConfig
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while configuring split: {e}")
    print()

result
# Out:
#                                                                                         splitConfig
# 0  {'testFraction': 0.25, 'validationFolds': 3, 'trainFraction': 0.6, 'negativeSamplingRatio': 1.0}

# %% [markdown]
# ### Adding the Machine Learning model
#
# As of now, during the time of writing this blog, GDS only supports Logistic Regression model which can be potentially used in production, so I am going to use the same model here. There are also Random Forest and MLP models available for us to use.

# %%
# Adding the model to pipeline
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.addLogisticRegression('pipe')
YIELD parameterSpace
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while adding logistic regression model: {e}")
    print()

result
# Out:
#                                                                                                                                                                                                                                                                          parameterSpace
# 0  {'MultilayerPerceptron': [], 'RandomForest': [], 'LogisticRegression': [{'minEpochs': 1, 'maxEpochs': 100, 'focusWeight': 0.0, 'patience': 1, 'tolerance': 0.001, 'learningRate': 0.001, 'batchSize': 100, 'penalty': 0.0, 'methodName': 'LogisticRegression', 'classWeights': []}]}

# %%
# Adding hyperparameters to be used
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.addLogisticRegression('pipe', {maxEpochs: 800, penalty: {range: [1e-4, 1e2]}})
YIELD parameterSpace
RETURN parameterSpace.LogisticRegression AS logisticRegressionSpace
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while adding logistic regression model with hyperparameters: {e}")
    print()

result
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                            logisticRegressionSpace
# 0  [{'minEpochs': 1, 'maxEpochs': 100, 'focusWeight': 0.0, 'patience': 1, 'tolerance': 0.001, 'learningRate': 0.001, 'batchSize': 100, 'penalty': 0.0, 'methodName': 'LogisticRegression', 'classWeights': []}, {'minEpochs': 1, 'maxEpochs': 800, 'focusWeight': 0.0, 'patience': 1, 'tolerance': 0.001, 'learningRate': 0.001, 'batchSize': 100, 'penalty': {'range': [0.0001, 100.0]}, 'methodName': 'LogisticRegression', 'classWeights': []}]

# %% [markdown]
# ### Configuring Auto-Tuning
#
# In order to find good models, the pipeline supports automatically tuning the parameters of the training algorithm. Optionally, the procedure described below can be used to configure the auto-tuning behavior. Otherwise, default auto-tuning configuration is used.

# %%
cypher_query = """
CALL gds.alpha.pipeline.linkPrediction.configureAutoTuning('pipe', {
  maxTrials: 3
}) YIELD autoTuningConfig
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while configuring auto-tuning: {e}")
    print()

result
# Out:
#    autoTuningConfig
# 0  {'maxTrials': 3}

# %% [markdown]
# ### Projecting the Graph from Neo4j Database
#
# Now this is a very important step. In order to use the data present in our database, we don’t need to directly connect to our database. We can just project the graph into memory and make changes (called as “mutate” in gds library) to the graph data. These changes won’t be reflected into the database unless we write them back, leaving us room to play around with.
#
# It is important to define the orientation of the graph as “UNDIRECTED”, irrespective of whatever direction it may have in the original graph.

# %%
# The name of our projected graph is myGraph
# It is important to define the orientation of the graph as “UNDIRECTED”, irrespective of whatever direction it may have in the original graph
cypher_query = """
CALL gds.graph.project(
  'recommendationGraph', 
  {
    User: {
      label: 'User'
    },
    Ingredient: {
      label: 'Ingredient'
    }
  },
  {
    LIKES: {
      type: 'LIKES',
      orientation: 'UNDIRECTED'
    },
    DISLIKES: {
      type: 'DISLIKES',
      orientation: 'UNDIRECTED'
    }
  }
)
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while projecting the graph: {e}")
    print()

result
# Out:
#                                                                                            nodeProjection  \
# 0  {'User': {'label': 'User', 'properties': {}}, 'Ingredient': {'label': 'Ingredient', 'properties': {}}}
#
#                                                                                                                                                                                                                                            relationshipProjection  \
# 0  {'DISLIKES': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'DISLIKES'}, 'LIKES': {'aggregation': 'DEFAULT', 'orientation': 'UNDIRECTED', 'indexInverse': False, 'properties': {}, 'type': 'LIKES'}}
#
#              graphName  nodeCount  relationshipCount  projectMillis
# 0  recommendationGraph       3096                252            785

# %% [markdown]
# ### Training the model for LIKES
#
# Now we are ready to actually train a LinkPrediction model. We must make sure to specify the targetRelationshipType to instruct the model to train only using that type. With the graph recommendationGraph there are actually no other relationship types projected, but that is not always the case.

# %%
# Here, we first pass the name of our projected graph, then a DICTIONARY object
# with the following parameters
cypher_query = """
CALL gds.beta.pipeline.linkPrediction.train('recommendationGraph', {
  pipeline: 'pipe',
  modelName: 'lp-pipeline-model',
  metrics: ['AUCPR', 'OUT_OF_BAG_ERROR'],
  targetRelationshipType: 'LIKES',
  randomSeed: 42
}) YIELD modelInfo, modelSelectionStats
RETURN
  modelInfo.bestParameters AS winningModel,
  modelInfo.metrics.AUCPR.train.avg AS avgTrainScore,
  modelInfo.metrics.AUCPR.outerTrain AS outerTrainScore,
  modelInfo.metrics.AUCPR.test AS testScore,
  [cand IN modelSelectionStats.modelCandidates | cand.metrics.AUCPR.validation.avg] AS validationScores
"""

try:
    result = gds.run_cypher(cypher_query)
except Exception as e:
    print(f"An error occurred while training link prediction model: {e}")
    print()

result
# Out:
#                                                                                                                                                                                                  winningModel  \
# 0  {'minEpochs': 1, 'maxEpochs': 100, 'focusWeight': 0.0, 'patience': 1, 'tolerance': 0.001, 'learningRate': 0.001, 'batchSize': 100, 'penalty': 0.0, 'methodName': 'LogisticRegression', 'classWeights': []}
#
#    avgTrainScore  outerTrainScore  testScore  \
# 0       0.864892         0.864865   0.797619
#
#                                                                    validationScores
# 0  [0.8177643843676452, 0.8177643843676452, 0.8177643843676452, 0.6235694740042567]

# %% [markdown]
# ### Using the model for inferencing
#
# Now, what we like to do for inferencing is to store (mutate) the predicted links back to my projected graph, and then using a simple query to only get me the new predicted links. In this way, we can train my model periodically, and store the results in the projected graph without the need to write anything back to the Database.

# %%
# threshold is the parameter used to filter out the predictions based on probability
# Only those values would be returned which have a probability > threshold

# topN would give us 24,000 predictions (as we defined our relationship as UNDIRECTED)

model = 'lp-pipeline-model'
graph = 'recommendationGraph'

def mutate(graph_name, **kwargs):
    config = dict(**kwargs)
    try:
        gds.run_cypher(
            """
            CALL gds.beta.pipeline.linkPrediction.predict.mutate($graph_name, $config)
            """,
            params={"graph_name": graph_name, "config": config}
        )
    except Exception as e:
        print(f"An error occurred while mutating the graph: {e}")
        print()

# Example call to the function
mutate(
    graph_name=graph,
    modelName=model,
    relationshipTypes=['LIKES'],
    mutateRelationshipType='LIKES_PREDICTED',
    topN=12000,
    threshold=0.4
)

# %%
df = gds.run_cypher("""
CALL gds.graph.relationships.stream($graphName)
YIELD sourceNodeId, targetNodeId, relationshipType
WHERE relationshipType='LIKES_PREDICTED'
RETURN gds.util.asNode(sourceNodeId).id AS source_id, gds.util.asNode(sourceNodeId).name AS source_name,
       gds.util.asNode(targetNodeId).id AS target_id, gds.util.asNode(targetNodeId).name AS target_name,
       relationshipType
ORDER BY source_id ASC, target_id ASC
""", params={'graphName': graph})

df = df.dropna(subset=['source_id'])
df = df[df['target_id'].isna()]

df.shape

# Saving as csv here so that you can look at the predicted results
df.to_csv('predicted.csv', index=False)
df
# Out:
#      source_id source_name  target_id         target_name relationshipType
# 12         1.0          Ch        NaN                fish  LIKES_PREDICTED
# 13         1.0          Ch        NaN          flatbreads  LIKES_PREDICTED
# 14         1.0          Ch        NaN              cereal  LIKES_PREDICTED
# 15         1.0          Ch        NaN             lettuce  LIKES_PREDICTED
# 16         1.0          Ch        NaN           Tia Maria  LIKES_PREDICTED
# 17         1.0          Ch        NaN              shrimp  LIKES_PREDICTED
# 18         1.0          Ch        NaN  mini chocolate egg  LIKES_PREDICTED
# 19         1.0          Ch        NaN               guava  LIKES_PREDICTED
# 20         1.0          Ch        NaN              pomelo  LIKES_PREDICTED
# 21         1.0          Ch        NaN             octopus  LIKES_PREDICTED
# 22         1.0          Ch        NaN        whey protein  LIKES_PREDICTED
# 23         1.0          Ch        NaN              durian  LIKES_PREDICTED
# 24         1.0          Ch        NaN              tomato  LIKES_PREDICTED
# 25         1.0          Ch        NaN      chicken breast  LIKES_PREDICTED
# 26         1.0          Ch        NaN           pineapple  LIKES_PREDICTED
# 27         1.0          Ch        NaN             spinach  LIKES_PREDICTED
# 28         1.0          Ch        NaN          strawberry  LIKES_PREDICTED
# 29         1.0          Ch        NaN              salmon  LIKES_PREDICTED
# 30         1.0          Ch        NaN           chocolate  LIKES_PREDICTED
# 31         1.0          Ch        NaN                pork  LIKES_PREDICTED
# 32         1.0          Ch        NaN              carrot  LIKES_PREDICTED
# 33         1.0          Ch        NaN            cucumber  LIKES_PREDICTED
# 34         1.0          Ch        NaN               peach  LIKES_PREDICTED
# 35         1.0          Ch        NaN             chicken  LIKES_PREDICTED
# 36         1.0          Ch        NaN           blueberry  LIKES_PREDICTED
# 37         1.0          Ch        NaN              orange  LIKES_PREDICTED
# 38         1.0          Ch        NaN              cherry  LIKES_PREDICTED
# 39         1.0          Ch        NaN                kale  LIKES_PREDICTED
# 40         1.0          Ch        NaN               mango  LIKES_PREDICTED
# 41         1.0          Ch        NaN               salad  LIKES_PREDICTED
# 42         1.0          Ch        NaN              banana  LIKES_PREDICTED
# 43         1.0          Ch        NaN               apple  LIKES_PREDICTED
# 44         1.0          Ch        NaN               steak  LIKES_PREDICTED
# 45         1.0          Ch        NaN       passion fruit  LIKES_PREDICTED
# 46         1.0          Ch        NaN         dried fruit  LIKES_PREDICTED
# 47         1.0          Ch        NaN                crab  LIKES_PREDICTED
# 48         1.0          Ch        NaN                tuna  LIKES_PREDICTED
# 49         1.0          Ch        NaN             mustard  LIKES_PREDICTED
# 50         1.0          Ch        NaN          grapefruit  LIKES_PREDICTED
# 51         1.0          Ch        NaN               grape  LIKES_PREDICTED
# 52         1.0          Ch        NaN                corn  LIKES_PREDICTED
# 53         1.0          Ch        NaN                oats  LIKES_PREDICTED
# 54         1.0          Ch        NaN                 pea  LIKES_PREDICTED
# 66         2.0          Tu        NaN              tomato  LIKES_PREDICTED
# 67         2.0          Tu        NaN                 egg  LIKES_PREDICTED
# 68         2.0          Tu        NaN           pineapple  LIKES_PREDICTED
# 69         2.0          Tu        NaN             spinach  LIKES_PREDICTED
# 70         2.0          Tu        NaN          strawberry  LIKES_PREDICTED
# 71         2.0          Tu        NaN              salmon  LIKES_PREDICTED
# 72         2.0          Tu        NaN           chocolate  LIKES_PREDICTED
# 73         2.0          Tu        NaN              carrot  LIKES_PREDICTED
# 74         2.0          Tu        NaN            cucumber  LIKES_PREDICTED
# 75         2.0          Tu        NaN               peach  LIKES_PREDICTED
# 76         2.0          Tu        NaN             chicken  LIKES_PREDICTED
# 77         2.0          Tu        NaN           blueberry  LIKES_PREDICTED
# 78         2.0          Tu        NaN              orange  LIKES_PREDICTED
# 79         2.0          Tu        NaN              cherry  LIKES_PREDICTED
# 80         2.0          Tu        NaN                kale  LIKES_PREDICTED
# 81         2.0          Tu        NaN               mango  LIKES_PREDICTED
# 82         2.0          Tu        NaN               salad  LIKES_PREDICTED
# 83         2.0          Tu        NaN           ice cream  LIKES_PREDICTED
# 84         2.0          Tu        NaN              banana  LIKES_PREDICTED
# 85         2.0          Tu        NaN               apple  LIKES_PREDICTED
# 86         2.0          Tu        NaN               steak  LIKES_PREDICTED
# 87         2.0          Tu        NaN       passion fruit  LIKES_PREDICTED
# 88         2.0          Tu        NaN                crab  LIKES_PREDICTED
# 89         2.0          Tu        NaN                tuna  LIKES_PREDICTED
# 90         2.0          Tu        NaN             mustard  LIKES_PREDICTED
# 91         2.0          Tu        NaN          grapefruit  LIKES_PREDICTED
# 92         2.0          Tu        NaN                cake  LIKES_PREDICTED
# 93         2.0          Tu        NaN               grape  LIKES_PREDICTED
# 94         2.0          Tu        NaN                corn  LIKES_PREDICTED
# 95         2.0          Tu        NaN                 pea  LIKES_PREDICTED
# 96         2.0          Tu        NaN                fish  LIKES_PREDICTED
# 97         2.0          Tu        NaN          flatbreads  LIKES_PREDICTED
# 98         2.0          Tu        NaN             lettuce  LIKES_PREDICTED
# 99         2.0          Tu        NaN           Tia Maria  LIKES_PREDICTED
# 100        2.0          Tu        NaN              shrimp  LIKES_PREDICTED
# 101        2.0          Tu        NaN  mini chocolate egg  LIKES_PREDICTED
# 102        2.0          Tu        NaN               guava  LIKES_PREDICTED
# 103        2.0          Tu        NaN              pomelo  LIKES_PREDICTED
# 104        2.0          Tu        NaN             octopus  LIKES_PREDICTED
# 105        2.0          Tu        NaN        whey protein  LIKES_PREDICTED
# 106        2.0          Tu        NaN              durian  LIKES_PREDICTED
# 119        3.0       Th Ng        NaN             octopus  LIKES_PREDICTED
# 120        3.0       Th Ng        NaN        whey protein  LIKES_PREDICTED
# 121        3.0       Th Ng        NaN              durian  LIKES_PREDICTED
# 122        3.0       Th Ng        NaN              tomato  LIKES_PREDICTED
# 123        3.0       Th Ng        NaN                 egg  LIKES_PREDICTED
# 124        3.0       Th Ng        NaN      chicken breast  LIKES_PREDICTED
# 125        3.0       Th Ng        NaN           pineapple  LIKES_PREDICTED
# 126        3.0       Th Ng        NaN             spinach  LIKES_PREDICTED
# 127        3.0       Th Ng        NaN          strawberry  LIKES_PREDICTED
# 128        3.0       Th Ng        NaN              salmon  LIKES_PREDICTED
# 129        3.0       Th Ng        NaN           chocolate  LIKES_PREDICTED
# 130        3.0       Th Ng        NaN                pork  LIKES_PREDICTED
# 131        3.0       Th Ng        NaN              carrot  LIKES_PREDICTED
# 132        3.0       Th Ng        NaN                milk  LIKES_PREDICTED
# 133        3.0       Th Ng        NaN            cucumber  LIKES_PREDICTED
# 134        3.0       Th Ng        NaN                beef  LIKES_PREDICTED
# 135        3.0       Th Ng        NaN               peach  LIKES_PREDICTED
# 136        3.0       Th Ng        NaN             chicken  LIKES_PREDICTED
# 137        3.0       Th Ng        NaN           blueberry  LIKES_PREDICTED
# 138        3.0       Th Ng        NaN              orange  LIKES_PREDICTED
# 139        3.0       Th Ng        NaN                kale  LIKES_PREDICTED
# 140        3.0       Th Ng        NaN               salad  LIKES_PREDICTED
# 141        3.0       Th Ng        NaN           ice cream  LIKES_PREDICTED
# 142        3.0       Th Ng        NaN              banana  LIKES_PREDICTED
# 143        3.0       Th Ng        NaN              yogurt  LIKES_PREDICTED
# 144        3.0       Th Ng        NaN               steak  LIKES_PREDICTED
# 145        3.0       Th Ng        NaN       passion fruit  LIKES_PREDICTED
# 146        3.0       Th Ng        NaN         dried fruit  LIKES_PREDICTED
# 147        3.0       Th Ng        NaN                crab  LIKES_PREDICTED
# 148        3.0       Th Ng        NaN                tuna  LIKES_PREDICTED
# 149        3.0       Th Ng        NaN             mustard  LIKES_PREDICTED
# 150        3.0       Th Ng        NaN          grapefruit  LIKES_PREDICTED
# 151        3.0       Th Ng        NaN                cake  LIKES_PREDICTED
# 152        3.0       Th Ng        NaN               grape  LIKES_PREDICTED
# 153        3.0       Th Ng        NaN                corn  LIKES_PREDICTED
# 154        3.0       Th Ng        NaN                oats  LIKES_PREDICTED
# 155        3.0       Th Ng        NaN             berries  LIKES_PREDICTED
# 156        3.0       Th Ng        NaN                 pea  LIKES_PREDICTED
# 157        3.0       Th Ng        NaN                fish  LIKES_PREDICTED
# 158        3.0       Th Ng        NaN          flatbreads  LIKES_PREDICTED
# 159        3.0       Th Ng        NaN              cereal  LIKES_PREDICTED
# 160        3.0       Th Ng        NaN             lettuce  LIKES_PREDICTED
# 161        3.0       Th Ng        NaN           Tia Maria  LIKES_PREDICTED
# 162        3.0       Th Ng        NaN              shrimp  LIKES_PREDICTED
# 163        3.0       Th Ng        NaN  mini chocolate egg  LIKES_PREDICTED
# 164        3.0       Th Ng        NaN              pomelo  LIKES_PREDICTED
# 177        4.0          Ro        NaN              tomato  LIKES_PREDICTED
# 178        4.0          Ro        NaN                 egg  LIKES_PREDICTED
# 179        4.0          Ro        NaN      chicken breast  LIKES_PREDICTED
# 180        4.0          Ro        NaN           pineapple  LIKES_PREDICTED
# 181        4.0          Ro        NaN             spinach  LIKES_PREDICTED
# 182        4.0          Ro        NaN          strawberry  LIKES_PREDICTED
# 183        4.0          Ro        NaN              salmon  LIKES_PREDICTED
# 184        4.0          Ro        NaN           chocolate  LIKES_PREDICTED
# 185        4.0          Ro        NaN                pork  LIKES_PREDICTED
# 186        4.0          Ro        NaN                milk  LIKES_PREDICTED
# 187        4.0          Ro        NaN            cucumber  LIKES_PREDICTED
# 188        4.0          Ro        NaN               peach  LIKES_PREDICTED
# 189        4.0          Ro        NaN           blueberry  LIKES_PREDICTED
# 190        4.0          Ro        NaN              cherry  LIKES_PREDICTED
# 191        4.0          Ro        NaN                kale  LIKES_PREDICTED
# 192        4.0          Ro        NaN               mango  LIKES_PREDICTED
# 193        4.0          Ro        NaN               salad  LIKES_PREDICTED
# 194        4.0          Ro        NaN           ice cream  LIKES_PREDICTED
# 195        4.0          Ro        NaN              yogurt  LIKES_PREDICTED
# 196        4.0          Ro        NaN               steak  LIKES_PREDICTED
# 197        4.0          Ro        NaN       passion fruit  LIKES_PREDICTED
# 198        4.0          Ro        NaN         dried fruit  LIKES_PREDICTED
# 199        4.0          Ro        NaN                crab  LIKES_PREDICTED
# 200        4.0          Ro        NaN                tuna  LIKES_PREDICTED
# 201        4.0          Ro        NaN             mustard  LIKES_PREDICTED
# 202        4.0          Ro        NaN          grapefruit  LIKES_PREDICTED
# 203        4.0          Ro        NaN                cake  LIKES_PREDICTED
# 204        4.0          Ro        NaN               grape  LIKES_PREDICTED
# 205        4.0          Ro        NaN                oats  LIKES_PREDICTED
# 206        4.0          Ro        NaN             berries  LIKES_PREDICTED
# 207        4.0          Ro        NaN                fish  LIKES_PREDICTED
# 208        4.0          Ro        NaN          flatbreads  LIKES_PREDICTED
# 209        4.0          Ro        NaN              cereal  LIKES_PREDICTED
# 210        4.0          Ro        NaN             lettuce  LIKES_PREDICTED
# 211        4.0          Ro        NaN           Tia Maria  LIKES_PREDICTED
# 212        4.0          Ro        NaN              shrimp  LIKES_PREDICTED
# 213        4.0          Ro        NaN  mini chocolate egg  LIKES_PREDICTED
# 214        4.0          Ro        NaN               guava  LIKES_PREDICTED
# 215        4.0          Ro        NaN              pomelo  LIKES_PREDICTED
# 216        4.0          Ro        NaN             octopus  LIKES_PREDICTED
# 217        4.0          Ro        NaN        whey protein  LIKES_PREDICTED
# 218        4.0          Ro        NaN              durian  LIKES_PREDICTED
# 231        5.0       Hu Vu        NaN              tomato  LIKES_PREDICTED
# 232        5.0       Hu Vu        NaN                 egg  LIKES_PREDICTED
# 233        5.0       Hu Vu        NaN      chicken breast  LIKES_PREDICTED
# 234        5.0       Hu Vu        NaN           pineapple  LIKES_PREDICTED
# 235        5.0       Hu Vu        NaN             spinach  LIKES_PREDICTED
# 236        5.0       Hu Vu        NaN              salmon  LIKES_PREDICTED
# 237        5.0       Hu Vu        NaN           chocolate  LIKES_PREDICTED
# 238        5.0       Hu Vu        NaN                pork  LIKES_PREDICTED
# 239        5.0       Hu Vu        NaN              carrot  LIKES_PREDICTED
# 240        5.0       Hu Vu        NaN                milk  LIKES_PREDICTED
# 241        5.0       Hu Vu        NaN            cucumber  LIKES_PREDICTED
# 242        5.0       Hu Vu        NaN                beef  LIKES_PREDICTED
# 243        5.0       Hu Vu        NaN               peach  LIKES_PREDICTED
# 244        5.0       Hu Vu        NaN             chicken  LIKES_PREDICTED
# 245        5.0       Hu Vu        NaN           blueberry  LIKES_PREDICTED
# 246        5.0       Hu Vu        NaN              orange  LIKES_PREDICTED
# 247        5.0       Hu Vu        NaN                kale  LIKES_PREDICTED
# 248        5.0       Hu Vu        NaN               mango  LIKES_PREDICTED
# 249        5.0       Hu Vu        NaN               salad  LIKES_PREDICTED
# 250        5.0       Hu Vu        NaN           ice cream  LIKES_PREDICTED
# 251        5.0       Hu Vu        NaN              banana  LIKES_PREDICTED
# 252        5.0       Hu Vu        NaN              yogurt  LIKES_PREDICTED
# 253        5.0       Hu Vu        NaN               steak  LIKES_PREDICTED
# 254        5.0       Hu Vu        NaN       passion fruit  LIKES_PREDICTED
# 255        5.0       Hu Vu        NaN         dried fruit  LIKES_PREDICTED
# 256        5.0       Hu Vu        NaN                crab  LIKES_PREDICTED
# 257        5.0       Hu Vu        NaN                tuna  LIKES_PREDICTED
# 258        5.0       Hu Vu        NaN             mustard  LIKES_PREDICTED
# 259        5.0       Hu Vu        NaN          grapefruit  LIKES_PREDICTED
# 260        5.0       Hu Vu        NaN                cake  LIKES_PREDICTED
# 261        5.0       Hu Vu        NaN               grape  LIKES_PREDICTED
# 262        5.0       Hu Vu        NaN                corn  LIKES_PREDICTED
# 263        5.0       Hu Vu        NaN                oats  LIKES_PREDICTED
# 264        5.0       Hu Vu        NaN             berries  LIKES_PREDICTED
# 265        5.0       Hu Vu        NaN                 pea  LIKES_PREDICTED
# 266        5.0       Hu Vu        NaN                fish  LIKES_PREDICTED
# 267        5.0       Hu Vu        NaN          flatbreads  LIKES_PREDICTED
# 268        5.0       Hu Vu        NaN              cereal  LIKES_PREDICTED
# 269        5.0       Hu Vu        NaN             lettuce  LIKES_PREDICTED
# 270        5.0       Hu Vu        NaN           Tia Maria  LIKES_PREDICTED
# 271        5.0       Hu Vu        NaN              shrimp  LIKES_PREDICTED
# 272        5.0       Hu Vu        NaN  mini chocolate egg  LIKES_PREDICTED
# 273        5.0       Hu Vu        NaN               guava  LIKES_PREDICTED
# 274        5.0       Hu Vu        NaN              pomelo  LIKES_PREDICTED
# 275        5.0       Hu Vu        NaN             octopus  LIKES_PREDICTED
# 276        5.0       Hu Vu        NaN        whey protein  LIKES_PREDICTED
# 277        5.0       Hu Vu        NaN              durian  LIKES_PREDICTED
# 290        6.0          Du        NaN            cucumber  LIKES_PREDICTED
# 291        6.0          Du        NaN               peach  LIKES_PREDICTED
# 292        6.0          Du        NaN           blueberry  LIKES_PREDICTED
# 293        6.0          Du        NaN              orange  LIKES_PREDICTED
# 294        6.0          Du        NaN              cherry  LIKES_PREDICTED
# 295        6.0          Du        NaN                kale  LIKES_PREDICTED
# 296        6.0          Du        NaN               salad  LIKES_PREDICTED
# 297        6.0          Du        NaN           ice cream  LIKES_PREDICTED
# 298        6.0          Du        NaN              banana  LIKES_PREDICTED
# 299        6.0          Du        NaN              yogurt  LIKES_PREDICTED
# 300        6.0          Du        NaN               steak  LIKES_PREDICTED
# 301        6.0          Du        NaN       passion fruit  LIKES_PREDICTED
# 302        6.0          Du        NaN         dried fruit  LIKES_PREDICTED
# 303        6.0          Du        NaN                crab  LIKES_PREDICTED
# 304        6.0          Du        NaN                tuna  LIKES_PREDICTED
# 305        6.0          Du        NaN             mustard  LIKES_PREDICTED
# 306        6.0          Du        NaN          grapefruit  LIKES_PREDICTED
# 307        6.0          Du        NaN                cake  LIKES_PREDICTED
# 308        6.0          Du        NaN                corn  LIKES_PREDICTED
# 309        6.0          Du        NaN                oats  LIKES_PREDICTED
# 310        6.0          Du        NaN             berries  LIKES_PREDICTED
# 311        6.0          Du        NaN                 pea  LIKES_PREDICTED
# 312        6.0          Du        NaN                fish  LIKES_PREDICTED
# 313        6.0          Du        NaN          flatbreads  LIKES_PREDICTED
# 314        6.0          Du        NaN              cereal  LIKES_PREDICTED
# 315        6.0          Du        NaN             lettuce  LIKES_PREDICTED
# 316        6.0          Du        NaN           Tia Maria  LIKES_PREDICTED
# 317        6.0          Du        NaN              shrimp  LIKES_PREDICTED
# 318        6.0          Du        NaN  mini chocolate egg  LIKES_PREDICTED
# 319        6.0          Du        NaN              pomelo  LIKES_PREDICTED
# 320        6.0          Du        NaN             octopus  LIKES_PREDICTED
# 321        6.0          Du        NaN        whey protein  LIKES_PREDICTED
# 322        6.0          Du        NaN              durian  LIKES_PREDICTED
# 323        6.0          Du        NaN              tomato  LIKES_PREDICTED
# 324        6.0          Du        NaN                 egg  LIKES_PREDICTED
# 325        6.0          Du        NaN      chicken breast  LIKES_PREDICTED
# 326        6.0          Du        NaN             spinach  LIKES_PREDICTED
# 327        6.0          Du        NaN          strawberry  LIKES_PREDICTED
# 328        6.0          Du        NaN              salmon  LIKES_PREDICTED
# 329        6.0          Du        NaN           chocolate  LIKES_PREDICTED
# 330        6.0          Du        NaN              carrot  LIKES_PREDICTED
# 331        6.0          Du        NaN                milk  LIKES_PREDICTED
# 343        7.0       Ph Tr        NaN                 egg  LIKES_PREDICTED
# 344        7.0       Ph Tr        NaN      chicken breast  LIKES_PREDICTED
# 345        7.0       Ph Tr        NaN           pineapple  LIKES_PREDICTED
# 346        7.0       Ph Tr        NaN          strawberry  LIKES_PREDICTED
# 347        7.0       Ph Tr        NaN              salmon  LIKES_PREDICTED
# 348        7.0       Ph Tr        NaN              carrot  LIKES_PREDICTED
# 349        7.0       Ph Tr        NaN                milk  LIKES_PREDICTED
# 350        7.0       Ph Tr        NaN               peach  LIKES_PREDICTED
# 351        7.0       Ph Tr        NaN             chicken  LIKES_PREDICTED
# 352        7.0       Ph Tr        NaN           blueberry  LIKES_PREDICTED
# 353        7.0       Ph Tr        NaN              orange  LIKES_PREDICTED
# 354        7.0       Ph Tr        NaN              cherry  LIKES_PREDICTED
# 355        7.0       Ph Tr        NaN               mango  LIKES_PREDICTED
# 356        7.0       Ph Tr        NaN               salad  LIKES_PREDICTED
# 357        7.0       Ph Tr        NaN           ice cream  LIKES_PREDICTED
# 358        7.0       Ph Tr        NaN              banana  LIKES_PREDICTED
# 359        7.0       Ph Tr        NaN               apple  LIKES_PREDICTED
# 360        7.0       Ph Tr        NaN              yogurt  LIKES_PREDICTED
# 361        7.0       Ph Tr        NaN               steak  LIKES_PREDICTED
# 362        7.0       Ph Tr        NaN       passion fruit  LIKES_PREDICTED
# 363        7.0       Ph Tr        NaN         dried fruit  LIKES_PREDICTED
# 364        7.0       Ph Tr        NaN                tuna  LIKES_PREDICTED
# 365        7.0       Ph Tr        NaN             mustard  LIKES_PREDICTED
# 366        7.0       Ph Tr        NaN                cake  LIKES_PREDICTED
# 367        7.0       Ph Tr        NaN               grape  LIKES_PREDICTED
# 368        7.0       Ph Tr        NaN                corn  LIKES_PREDICTED
# 369        7.0       Ph Tr        NaN                oats  LIKES_PREDICTED
# 370        7.0       Ph Tr        NaN             berries  LIKES_PREDICTED
# 371        7.0       Ph Tr        NaN                 pea  LIKES_PREDICTED
# 372        7.0       Ph Tr        NaN          flatbreads  LIKES_PREDICTED
# 373        7.0       Ph Tr        NaN              cereal  LIKES_PREDICTED
# 374        7.0       Ph Tr        NaN             lettuce  LIKES_PREDICTED
# 375        7.0       Ph Tr        NaN           Tia Maria  LIKES_PREDICTED
# 376        7.0       Ph Tr        NaN  mini chocolate egg  LIKES_PREDICTED
# 377        7.0       Ph Tr        NaN               guava  LIKES_PREDICTED
# 378        7.0       Ph Tr        NaN              pomelo  LIKES_PREDICTED
# 379        7.0       Ph Tr        NaN              durian  LIKES_PREDICTED
# 392        8.0          St        NaN             lettuce  LIKES_PREDICTED
# 393        8.0          St        NaN           Tia Maria  LIKES_PREDICTED
# 394        8.0          St        NaN              shrimp  LIKES_PREDICTED
# 395        8.0          St        NaN  mini chocolate egg  LIKES_PREDICTED
# 396        8.0          St        NaN               guava  LIKES_PREDICTED
# 397        8.0          St        NaN              pomelo  LIKES_PREDICTED
# 398        8.0          St        NaN             octopus  LIKES_PREDICTED
# 399        8.0          St        NaN        whey protein  LIKES_PREDICTED
# 400        8.0          St        NaN              durian  LIKES_PREDICTED
# 401        8.0          St        NaN              tomato  LIKES_PREDICTED
# 402        8.0          St        NaN                 egg  LIKES_PREDICTED
# 403        8.0          St        NaN      chicken breast  LIKES_PREDICTED
# 404        8.0          St        NaN           pineapple  LIKES_PREDICTED
# 405        8.0          St        NaN             spinach  LIKES_PREDICTED
# 406        8.0          St        NaN          strawberry  LIKES_PREDICTED
# 407        8.0          St        NaN           chocolate  LIKES_PREDICTED
# 408        8.0          St        NaN              carrot  LIKES_PREDICTED
# 409        8.0          St        NaN                milk  LIKES_PREDICTED
# 410        8.0          St        NaN            cucumber  LIKES_PREDICTED
# 411        8.0          St        NaN               peach  LIKES_PREDICTED
# 412        8.0          St        NaN             chicken  LIKES_PREDICTED
# 413        8.0          St        NaN              orange  LIKES_PREDICTED
# 414        8.0          St        NaN                kale  LIKES_PREDICTED
# 415        8.0          St        NaN               mango  LIKES_PREDICTED
# 416        8.0          St        NaN           ice cream  LIKES_PREDICTED
# 417        8.0          St        NaN              banana  LIKES_PREDICTED
# 418        8.0          St        NaN               apple  LIKES_PREDICTED
# 419        8.0          St        NaN              yogurt  LIKES_PREDICTED
# 420        8.0          St        NaN               steak  LIKES_PREDICTED
# 421        8.0          St        NaN       passion fruit  LIKES_PREDICTED
# 422        8.0          St        NaN         dried fruit  LIKES_PREDICTED
# 423        8.0          St        NaN                crab  LIKES_PREDICTED
# 424        8.0          St        NaN                tuna  LIKES_PREDICTED
# 425        8.0          St        NaN             mustard  LIKES_PREDICTED
# 426        8.0          St        NaN          grapefruit  LIKES_PREDICTED
# 427        8.0          St        NaN                cake  LIKES_PREDICTED
# 428        8.0          St        NaN               grape  LIKES_PREDICTED
# 429        8.0          St        NaN                corn  LIKES_PREDICTED
# 430        8.0          St        NaN                oats  LIKES_PREDICTED
# 431        8.0          St        NaN             berries  LIKES_PREDICTED
# 432        8.0          St        NaN                 pea  LIKES_PREDICTED
# 433        8.0          St        NaN                fish  LIKES_PREDICTED
# 434        8.0          St        NaN          flatbreads  LIKES_PREDICTED
# 435        8.0          St        NaN              cereal  LIKES_PREDICTED
# 447        9.0          Ow        NaN                 egg  LIKES_PREDICTED
# 448        9.0          Ow        NaN      chicken breast  LIKES_PREDICTED
# 449        9.0          Ow        NaN           pineapple  LIKES_PREDICTED
# 450        9.0          Ow        NaN          strawberry  LIKES_PREDICTED
# 451        9.0          Ow        NaN                pork  LIKES_PREDICTED
# 452        9.0          Ow        NaN              carrot  LIKES_PREDICTED
# 453        9.0          Ow        NaN                milk  LIKES_PREDICTED
# 454        9.0          Ow        NaN                beef  LIKES_PREDICTED
# 455        9.0          Ow        NaN               peach  LIKES_PREDICTED
# 456        9.0          Ow        NaN           blueberry  LIKES_PREDICTED
# 457        9.0          Ow        NaN              orange  LIKES_PREDICTED
# 458        9.0          Ow        NaN              cherry  LIKES_PREDICTED
# 459        9.0          Ow        NaN               mango  LIKES_PREDICTED
# 460        9.0          Ow        NaN               salad  LIKES_PREDICTED
# 461        9.0          Ow        NaN           ice cream  LIKES_PREDICTED
# 462        9.0          Ow        NaN              banana  LIKES_PREDICTED
# 463        9.0          Ow        NaN              yogurt  LIKES_PREDICTED
# 464        9.0          Ow        NaN               steak  LIKES_PREDICTED
# 465        9.0          Ow        NaN       passion fruit  LIKES_PREDICTED
# 466        9.0          Ow        NaN         dried fruit  LIKES_PREDICTED
# 467        9.0          Ow        NaN                tuna  LIKES_PREDICTED
# 468        9.0          Ow        NaN             mustard  LIKES_PREDICTED
# 469        9.0          Ow        NaN                cake  LIKES_PREDICTED
# 470        9.0          Ow        NaN               grape  LIKES_PREDICTED
# 471        9.0          Ow        NaN                corn  LIKES_PREDICTED
# 472        9.0          Ow        NaN                oats  LIKES_PREDICTED
# 473        9.0          Ow        NaN             berries  LIKES_PREDICTED
# 474        9.0          Ow        NaN                 pea  LIKES_PREDICTED
# 475        9.0          Ow        NaN          flatbreads  LIKES_PREDICTED
# 476        9.0          Ow        NaN              cereal  LIKES_PREDICTED
# 477        9.0          Ow        NaN             lettuce  LIKES_PREDICTED
# 478        9.0          Ow        NaN           Tia Maria  LIKES_PREDICTED
# 479        9.0          Ow        NaN              shrimp  LIKES_PREDICTED
# 480        9.0          Ow        NaN  mini chocolate egg  LIKES_PREDICTED
# 481        9.0          Ow        NaN               guava  LIKES_PREDICTED
# 482        9.0          Ow        NaN              pomelo  LIKES_PREDICTED
# 483        9.0          Ow        NaN              durian  LIKES_PREDICTED
# 496       10.0          Da        NaN              tomato  LIKES_PREDICTED
# 497       10.0          Da        NaN                 egg  LIKES_PREDICTED
# 498       10.0          Da        NaN      chicken breast  LIKES_PREDICTED
# 499       10.0          Da        NaN           pineapple  LIKES_PREDICTED
# 500       10.0          Da        NaN             spinach  LIKES_PREDICTED
# 501       10.0          Da        NaN              salmon  LIKES_PREDICTED
# 502       10.0          Da        NaN           chocolate  LIKES_PREDICTED
# 503       10.0          Da        NaN                pork  LIKES_PREDICTED
# 504       10.0          Da        NaN              carrot  LIKES_PREDICTED
# 505       10.0          Da        NaN                milk  LIKES_PREDICTED
# 506       10.0          Da        NaN            cucumber  LIKES_PREDICTED
# 507       10.0          Da        NaN                beef  LIKES_PREDICTED
# 508       10.0          Da        NaN               peach  LIKES_PREDICTED
# 509       10.0          Da        NaN             chicken  LIKES_PREDICTED
# 510       10.0          Da        NaN           blueberry  LIKES_PREDICTED
# 511       10.0          Da        NaN                kale  LIKES_PREDICTED
# 512       10.0          Da        NaN               salad  LIKES_PREDICTED
# 513       10.0          Da        NaN           ice cream  LIKES_PREDICTED
# 514       10.0          Da        NaN              banana  LIKES_PREDICTED
# 515       10.0          Da        NaN              yogurt  LIKES_PREDICTED
# 516       10.0          Da        NaN               steak  LIKES_PREDICTED
# 517       10.0          Da        NaN       passion fruit  LIKES_PREDICTED
# 518       10.0          Da        NaN         dried fruit  LIKES_PREDICTED
# 519       10.0          Da        NaN                crab  LIKES_PREDICTED
# 520       10.0          Da        NaN                tuna  LIKES_PREDICTED
# 521       10.0          Da        NaN             mustard  LIKES_PREDICTED
# 522       10.0          Da        NaN          grapefruit  LIKES_PREDICTED
# 523       10.0          Da        NaN                cake  LIKES_PREDICTED
# 524       10.0          Da        NaN               grape  LIKES_PREDICTED
# 525       10.0          Da        NaN                corn  LIKES_PREDICTED
# 526       10.0          Da        NaN                oats  LIKES_PREDICTED
# 527       10.0          Da        NaN             berries  LIKES_PREDICTED
# 528       10.0          Da        NaN                 pea  LIKES_PREDICTED
# 529       10.0          Da        NaN                fish  LIKES_PREDICTED
# 530       10.0          Da        NaN          flatbreads  LIKES_PREDICTED
# 531       10.0          Da        NaN              cereal  LIKES_PREDICTED
# 532       10.0          Da        NaN             lettuce  LIKES_PREDICTED
# 533       10.0          Da        NaN           Tia Maria  LIKES_PREDICTED
# 534       10.0          Da        NaN              shrimp  LIKES_PREDICTED
# 535       10.0          Da        NaN  mini chocolate egg  LIKES_PREDICTED
# 536       10.0          Da        NaN               guava  LIKES_PREDICTED
# 537       10.0          Da        NaN             octopus  LIKES_PREDICTED
# 538       10.0          Da        NaN        whey protein  LIKES_PREDICTED
# 551       11.0          Do        NaN             spinach  LIKES_PREDICTED
# 552       11.0          Do        NaN              salmon  LIKES_PREDICTED
# 553       11.0          Do        NaN           chocolate  LIKES_PREDICTED
# 554       11.0          Do        NaN                pork  LIKES_PREDICTED
# 555       11.0          Do        NaN              carrot  LIKES_PREDICTED
# 556       11.0          Do        NaN                milk  LIKES_PREDICTED
# 557       11.0          Do        NaN            cucumber  LIKES_PREDICTED
# 558       11.0          Do        NaN                beef  LIKES_PREDICTED
# 559       11.0          Do        NaN               peach  LIKES_PREDICTED
# 680       13.0          Ph        NaN                 pea  LIKES_PREDICTED
# 681       13.0          Ph        NaN                fish  LIKES_PREDICTED
# 682       13.0          Ph        NaN          flatbreads  LIKES_PREDICTED
# 683       13.0          Ph        NaN              cereal  LIKES_PREDICTED
# 684       13.0          Ph        NaN           Tia Maria  LIKES_PREDICTED
# 685       13.0          Ph        NaN  mini chocolate egg  LIKES_PREDICTED
# 686       13.0          Ph        NaN               guava  LIKES_PREDICTED
# 687       13.0          Ph        NaN              pomelo  LIKES_PREDICTED
# 688       13.0          Ph        NaN             octopus  LIKES_PREDICTED
# 689       13.0          Ph        NaN        whey protein  LIKES_PREDICTED
# 690       13.0          Ph        NaN              durian  LIKES_PREDICTED

# %% [markdown]
# ### Suggesting nutrient foods

# %%
# Create a dictionary of predicted liked ingredients by user
predicted_likes_dict = df.groupby('source_id')['target_name'].apply(list).to_dict()
predicted_likes_dict
# Out:
# {1.0: ['fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian',
#   'tomato',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'salmon',
#   'chocolate',
#   'pork',
#   'carrot',
#   'cucumber',
#   'peach',
#   'chicken',
#   'blueberry',
#   'orange',
#   'cherry',
#   'kale',
#   'mango',
#   'salad',
#   'banana',
#   'apple',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'grape',
#   'corn',
#   'oats',
#   'pea'],
#  2.0: ['tomato',
#   'egg',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'salmon',
#   'chocolate',
#   'carrot',
#   'cucumber',
#   'peach',
#   'chicken',
#   'blueberry',
#   'orange',
#   'cherry',
#   'kale',
#   'mango',
#   'salad',
#   'ice cream',
#   'banana',
#   'apple',
#   'steak',
#   'passion fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'pea',
#   'fish',
#   'flatbreads',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian'],
#  3.0: ['octopus',
#   'whey protein',
#   'durian',
#   'tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'salmon',
#   'chocolate',
#   'pork',
#   'carrot',
#   'milk',
#   'cucumber',
#   'beef',
#   'peach',
#   'chicken',
#   'blueberry',
#   'orange',
#   'kale',
#   'salad',
#   'ice cream',
#   'banana',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'pomelo'],
#  4.0: ['tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'salmon',
#   'chocolate',
#   'pork',
#   'milk',
#   'cucumber',
#   'peach',
#   'blueberry',
#   'cherry',
#   'kale',
#   'mango',
#   'salad',
#   'ice cream',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'oats',
#   'berries',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian'],
#  5.0: ['tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'salmon',
#   'chocolate',
#   'pork',
#   'carrot',
#   'milk',
#   'cucumber',
#   'beef',
#   'peach',
#   'chicken',
#   'blueberry',
#   'orange',
#   'kale',
#   'mango',
#   'salad',
#   'ice cream',
#   'banana',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian'],
#  6.0: ['cucumber',
#   'peach',
#   'blueberry',
#   'orange',
#   'cherry',
#   'kale',
#   'salad',
#   'ice cream',
#   'banana',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian',
#   'tomato',
#   'egg',
#   'chicken breast',
#   'spinach',
#   'strawberry',
#   'salmon',
#   'chocolate',
#   'carrot',
#   'milk'],
#  7.0: ['egg',
#   'chicken breast',
#   'pineapple',
#   'strawberry',
#   'salmon',
#   'carrot',
#   'milk',
#   'peach',
#   'chicken',
#   'blueberry',
#   'orange',
#   'cherry',
#   'mango',
#   'salad',
#   'ice cream',
#   'banana',
#   'apple',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'tuna',
#   'mustard',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'durian'],
#  8.0: ['lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian',
#   'tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'chocolate',
#   'carrot',
#   'milk',
#   'cucumber',
#   'peach',
#   'chicken',
#   'orange',
#   'kale',
#   'mango',
#   'ice cream',
#   'banana',
#   'apple',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal'],
#  9.0: ['egg',
#   'chicken breast',
#   'pineapple',
#   'strawberry',
#   'pork',
#   'carrot',
#   'milk',
#   'beef',
#   'peach',
#   'blueberry',
#   'orange',
#   'cherry',
#   'mango',
#   'salad',
#   'ice cream',
#   'banana',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'tuna',
#   'mustard',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'durian'],
#  10.0: ['tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'salmon',
#   'chocolate',
#   'pork',
#   'carrot',
#   'milk',
#   'cucumber',
#   'beef',
#   'peach',
#   'chicken',
#   'blueberry',
#   'kale',
#   'salad',
#   'ice cream',
#   'banana',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'octopus',
#   'whey protein'],
#  11.0: ['spinach',
#   'salmon',
#   'chocolate',
#   'pork',
#   'carrot',
#   'milk',
#   'cucumber',
#   'beef',
#   'peach',
#   'blueberry',
#   'orange',
#   'cherry',
#   'kale',
#   'mango',
#   'salad',
#   'ice cream',
#   'yogurt',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'grapefruit',
#   'cake',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'lettuce',
#   'Tia Maria',
#   'shrimp',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian',
#   'tomato',
#   'egg',
#   'chicken breast',
#   'pineapple'],
#  12.0: ['octopus',
#   'durian',
#   'pineapple',
#   'strawberry',
#   'salmon',
#   'pork',
#   'carrot',
#   'beef',
#   'peach',
#   'blueberry',
#   'orange',
#   'cherry',
#   'mango',
#   'salad',
#   'ice cream',
#   'banana',
#   'apple',
#   'steak',
#   'passion fruit',
#   'crab',
#   'tuna',
#   'mustard',
#   'cake',
#   'grape',
#   'corn',
#   'pea',
#   'flatbreads',
#   'lettuce',
#   'Tia Maria',
#   'mini chocolate egg',
#   'guava',
#   'pomelo'],
#  13.0: ['tomato',
#   'egg',
#   'chicken breast',
#   'pineapple',
#   'spinach',
#   'strawberry',
#   'chocolate',
#   'pork',
#   'carrot',
#   'milk',
#   'cucumber',
#   'beef',
#   'chicken',
#   'blueberry',
#   'orange',
#   'kale',
#   'mango',
#   'salad',
#   'apple',
#   'yogurt',
#   'steak',
#   'passion fruit',
#   'dried fruit',
#   'crab',
#   'grapefruit',
#   'grape',
#   'corn',
#   'oats',
#   'berries',
#   'pea',
#   'fish',
#   'flatbreads',
#   'cereal',
#   'Tia Maria',
#   'mini chocolate egg',
#   'guava',
#   'pomelo',
#   'octopus',
#   'whey protein',
#   'durian']}

# %%
def get_user_recipes(user_id, predicted_liked_ingredients):
    cypher_query = """
    MATCH (u:User {id: $userId})
    OPTIONAL MATCH (u)-[:LIKES]->(liked:Ingredient)
    OPTIONAL MATCH (u)-[:DISLIKES]->(disliked:Ingredient)
    OPTIONAL MATCH (u)-[:ALLERGIC_TO]->(allergic:Ingredient)
    OPTIONAL MATCH (u)-[:HAS_DIET]->(d:DietType)
    WITH 
        u,  // Include u here so it is in scope
        COLLECT(liked.name) AS likedIngredients,
        COLLECT(disliked.name) AS dislikedIngredients,
        COLLECT(allergic.name) AS allergicIngredients,
        COLLECT(DISTINCT d.name) AS dietTypes,
        $predictedLikedIngredients AS predictedLikedIngredients

    // Combine actual and predicted liked ingredients
    WITH 
        u,
        likedIngredients + predictedLikedIngredients AS allLikedIngredients,
        dislikedIngredients,
        allergicIngredients,
        dietTypes

    MATCH (r:Recipe)-[:DIET_TYPE]->(rd:DietType)
    WHERE rd.name IN dietTypes  // Ensure the diet type is in the user's diet types
        AND none(i IN dislikedIngredients WHERE exists((r)-[:CONTAINS_INGREDIENT]->(:Ingredient {name: i})))
        AND none(i IN allergicIngredients WHERE exists((r)-[:CONTAINS_INGREDIENT]->(:Ingredient {name: i})))
    WITH 
        u,
        r, 
        rd,
        [(r)-[:CONTAINS_INGREDIENT]->(i:Ingredient) | i.name] AS ingredients,
        allLikedIngredients
    WITH
        u,
        r, 
        rd,
        ingredients,
        [i IN ingredients WHERE i IN allLikedIngredients] AS matchedLikedIngredients,
        size(ingredients) AS numTotalIngredients
    RETURN u.name AS userName,  // Return user name
           r.name AS recipe,
           r.description AS description,  // Ensure the recipe node has a description property
           r.nAddedSugar AS addedSugar,  // Ensure these properties exist on the recipe node
           r.nCarbohydrate AS carbohydrate,
           r.nFat AS fat,
           r.nKcal AS kcal,
           r.nProtein AS protein,
           r.nSalt AS salt,
           r.nSaturatedFat AS saturatedFat,
           rd.name AS recipeDietType,
           ingredients,
           size(matchedLikedIngredients) AS numLikedIngredients,
           numTotalIngredients
    ORDER BY numLikedIngredients DESC, numTotalIngredients ASC
    LIMIT 20
    """

    # Execute the query
    result = gds.run_cypher(cypher_query, params={'userId': user_id, 'predictedLikedIngredients': predicted_liked_ingredients})
    recipes = result.to_dict(orient='records')

    return recipes

def get_all_users():
    # Define the Cypher query to retrieve all user IDs
    cypher_query = """
    MATCH (u:User)
    RETURN u.id AS userId
    """
    
    result = gds.run_cypher(cypher_query)
    user_ids = result['userId'].tolist()

    return user_ids

# Main function to get recipes for all users
def get_recipes_for_all_users():
    user_ids = get_all_users()
    all_user_recipes = {}
    
    for user_id in user_ids:
        predicted_liked_ingredients = predicted_likes_dict.get(user_id, [])
        recipes = get_user_recipes(user_id, predicted_liked_ingredients)
        all_user_recipes[user_id] = recipes
    
    return all_user_recipes

# Assuming all_user_recipes is a dictionary where key is user_id and value is a list of recipes
def convert_to_dataframe(all_user_recipes):
    # Create a list to hold all rows of data
    data = []
    
    # Iterate over each user and their recipes
    for user_id, recipes in all_user_recipes.items():
        # Check if recipes is a DataFrame or a list of dictionaries
        if isinstance(recipes, pd.DataFrame):
            # Convert the recipes DataFrame to a list of dictionaries
            for _, row in recipes.iterrows():
                # Append each recipe and user_id as a new row in the data list
                data.append({
                    'user_id': user_id,
                    'user_name': row['userName'],
                    'recipe': row['recipe'],
                    'description': row['description'],
                    'added_sugar': row['addedSugar'],
                    'carbohydrate': row['carbohydrate'],
                    'fat': row['fat'],
                    'kcal': row['kcal'],
                    'protein': row['protein'],
                    'salt': row['salt'],
                    'saturated_fat': row['saturatedFat'],
                    'recipe_diet_type': row['recipeDietType'],
                    'ingredients': ', '.join(row['ingredients']),  # Convert list to comma-separated string
                    'num_liked_ingredients': row['numLikedIngredients'],
                    'num_total_ingredients': row['numTotalIngredients']
                })
        elif isinstance(recipes, list):
            # If recipes is a list of dictionaries
            for recipe in recipes:
                # Append each recipe and user_id as a new row in the data list
                data.append({
                    'user_id': user_id,
                    'user_name': recipe.get('userName', ''),
                    'recipe': recipe.get('recipe', ''),
                    'description': recipe.get('description', ''),
                    'added_sugar': recipe.get('addedSugar', ''),
                    'carbohydrate': recipe.get('carbohydrate', ''),
                    'fat': recipe.get('fat', ''),
                    'kcal': recipe.get('kcal', ''),
                    'protein': recipe.get('protein', ''),
                    'salt': recipe.get('salt', ''),
                    'saturated_fat': recipe.get('saturatedFat', ''),
                    'recipe_diet_type': recipe.get('recipeDietType', ''),
                    'ingredients': ', '.join(recipe.get('ingredients', [])),  # Convert list to comma-separated string
                    'num_liked_ingredients': recipe.get('numLikedIngredients', 0),
                    'num_total_ingredients': recipe.get('numTotalIngredients', 0)
                })
    
    # Create a DataFrame from the data list
    df = pd.DataFrame(data)
    
    return df

# Example usage
all_user_recipes = get_recipes_for_all_users()
df_result = convert_to_dataframe(all_user_recipes)

df_result.to_csv('predicted_knowledge_graph_based.csv', encoding='utf-8', index=False)
df_result
# Out:
#      user_id user_name  \
# 0          1        Ch
# 1          1        Ch
# 2          1        Ch
# 3          1        Ch
# 4          1        Ch
# 5          1        Ch
# 6          1        Ch
# 7          1        Ch
# 8          1        Ch
# 9          1        Ch
# 10         1        Ch
# 11         1        Ch
# 12         1        Ch
# 13         1        Ch
# 14         1        Ch
# 15         1        Ch
# 16         1        Ch
# 17         1        Ch
# 18         1        Ch
# 19         1        Ch
# 20         2        Tu
# 21         2        Tu
# 22         2        Tu
# 23         2        Tu
# 24         2        Tu
# 25         2        Tu
# 26         2        Tu
# 27         2        Tu
# 28         2        Tu
# 29         2        Tu
# 30         2        Tu
# 31         2        Tu
# 32         2        Tu
# 33         2        Tu
# 34         2        Tu
# 35         2        Tu
# 36         2        Tu
# 37         2        Tu
# 38         2        Tu
# 39         2        Tu
# 40         3     Th Ng
# 41         3     Th Ng
# 42         3     Th Ng
# 43         3     Th Ng
# 44         3     Th Ng
# 45         3     Th Ng
# 46         3     Th Ng
# 47         3     Th Ng
# 48         3     Th Ng
# 49         3     Th Ng
# 50         3     Th Ng
# 51         3     Th Ng
# 52         3     Th Ng
# 53         3     Th Ng
# 54         3     Th Ng
# 55         3     Th Ng
# 56         3     Th Ng
# 57         3     Th Ng
# 58         3     Th Ng
# 59         3     Th Ng
# 60         4        Ro
# 61         4        Ro
# 62         4        Ro
# 63         4        Ro
# 64         4        Ro
# 65         4        Ro
# 66         4        Ro
# 67         4        Ro
# 68         4        Ro
# 69         4        Ro
# 70         4        Ro
# 71         4        Ro
# 72         4        Ro
# 73         4        Ro
# 74         4        Ro
# 75         4        Ro
# 76         4        Ro
# 77         4        Ro
# 78         4        Ro
# 79         4        Ro
# 80         5     Hu Vu
# 81         5     Hu Vu
# 82         5     Hu Vu
# 83         5     Hu Vu
# 84         5     Hu Vu
# 85         5     Hu Vu
# 86         5     Hu Vu
# 87         5     Hu Vu
# 88         5     Hu Vu
# 89         5     Hu Vu
# 90         5     Hu Vu
# 91         5     Hu Vu
# 92         5     Hu Vu
# 93         5     Hu Vu
# 94         5     Hu Vu
# 95         5     Hu Vu
# 96         5     Hu Vu
# 97         5     Hu Vu
# 98         5     Hu Vu
# 99         5     Hu Vu
# 100        6        Du
# 101        6        Du
# 102        6        Du
# 103        6        Du
# 104        6        Du
# 105        6        Du
# 106        6        Du
# 107        6        Du
# 108        6        Du
# 109        6        Du
# 110        6        Du
# 111        6        Du
# 112        6        Du
# 113        6        Du
# 114        6        Du
# 115        6        Du
# 116        6        Du
# 117        6        Du
# 118        6        Du
# 119        6        Du
# 120        7     Ph Tr
# 121        7     Ph Tr
# 122        7     Ph Tr
# 123        8        St
# 124        8        St
# 125        8        St
# 126        8        St
# 127        8        St
# 128        8        St
# 129        8        St
# 130        8        St
# 131        8        St
# 132        8        St
# 133        8        St
# 134        8        St
# 135        8        St
# 136        8        St
# 137        8        St
# 138        8        St
# 139        8        St
# 140        8        St
# 141        8        St
# 142        8        St
# 143        9        Ow
# 144        9        Ow
# 145        9        Ow
# 146        9        Ow
# 147        9        Ow
# 148        9        Ow
# 149        9        Ow
# 150        9        Ow
# 151        9        Ow
# 152        9        Ow
# 153        9        Ow
# 154        9        Ow
# 155        9        Ow
# 156        9        Ow
# 157        9        Ow
# 158        9        Ow
# 159        9        Ow
# 160        9        Ow
# 161        9        Ow
# 162        9        Ow
# 163       10        Da
# 164       10        Da
# 165       10        Da
# 166       10        Da
# 167       10        Da
# 168       10        Da
# 169       10        Da
# 170       10        Da
# 171       10        Da
# 241                                                                                                                                                                                                                                                                     pea, tomato, fennel bulb, gooseberry, salad, rapeseed oil, carrot, onion, spelt, celery
# 242                                                                                                                                                                                                                                                                     pea, tomato, fennel bulb, gooseberry, salad, rapeseed oil, carrot, onion, spelt, celery
#
#      num_liked_ingredients  num_total_ingredients
# 0                        5                      9
# 1                        4                      6
# 2                        4                      9
# 3                        4                     10
# 4                        4                     11
# 5                        4                     13
# 6                        4                     13
# 7                        4                     14
# 8                        3                      4
# 9                        3                      5
# 10                       3                      7
# 11                       3                      7
# 12                       3                      7
# 13                       3                      8
# 14                       3                      8
# 15                       3                      8
# 16                       3                      8
# 17                       3                      8
# 18                       3                      9
# 19                       3                      9
# 20                       6                     16
# 21                       6                     29
# 22                       5                      8
# 23                       5                      9
# 24                       5                      9
# 25                       5                      9
# 26                       4                      6
# 27                       4                      6
# 28                       4                      9
# 29                       4                      9
# 30                       4                      9
# 31                       4                     10
# 32                       4                     10
# 33                       4                     10
# 34                       4                     10
# 35                       4                     10
# 36                       4                     11
# 37                       4                     12
# 38                       4                     12
# 39                       4                     12
# 40                       5                      9
# 41                       5                     14
# 42                       4                      6
# 43                       4                      9
# 44                       4                     10
# 45                       4                     11
# 46                       4                     13
# 47                       4                     13
# 48                       4                     14
# 49                       4                     14
# 50                       3                      4
# 51                       3                      5
# 52                       3                      5
# 53                       3                      6
# 54                       3                      6
# 55                       3                      7
# 56                       3                      7
# 57                       3                      7
# 58                       3                      8
# 59                       3                      8
# 60                       6                     16
# 61                       6                     29
# 62                       5                      8
# 63                       5                      9
# 64                       5                      9
# 65                       5                      9
# 66                       5                     10
# 67                       5                     14
# 68                       4                      6
# 69                       4                      6
# 70                       4                      6
# 71                       4                      9
# 72                       4                      9
# 73                       4                      9
# 74                       4                     10
# 75                       4                     10
# 76                       4                     10
# 77                       4                     11
# 78                       4                     11
# 79                       4                     12
# 80                       5                      9
# 81                       5                     14
# 82                       4                      6
# 83                       4                      6
# 84                       4                      9
# 85                       4                     10
# 86                       4                     10
# 87                       4                     11
# 88                       4                     13
# 89                       4                     13
# 90                       4                     14
# 91                       4                     14
# 92                       3                      4
# 93                       3                      5
# 94                       3                      5
# 95                       3                      5
# 96                       3                      6
# 97                       3                      6
# 98                       3                      7
# 99                       3                      7
# 100                      6                     16
# 101                      6                     29
# 102                      5                      9
# 103                      5                      9
# 104                      5                      9
# 105                      5                     10
# 106                      5                     14
# 107                      5                     14
# 108                      4                      6
# 109                      4                      6
# 110                      4                      6
# 111                      4                      9
# 112                      4                      9
# 113                      4                      9
# 114                      4                      9
# 115                      4                     10
# 116                      4                     10
# 117                      4                     11
# 118                      4                     11
# 119                      4                     11
# 120                      1                      4
# 121                      0                      2
# 122                      0                      2
# 123                      6                     16
# 124                      6                     29
# 125                      5                      8
# 126                      5                      9
# 127                      5                      9
# 128                      5                      9
# 129                      5                      9
# 130                      5                     10
# 131                      5                     14
# 132                      5                     14
# 133                      4                      6
# 134                      4                      6
# 135                      4                      6
# 136                      4                      6
# 137                      4                      9
# 138                      4                      9
# 139                      4                      9
# 140                      4                      9
# 141                      4                     10
# 142                      4                     10
# 143                      5                      9
# 144                      5                     14
# 145                      4                      6
# 146                      4                      9
# 147                      4                     10
# 148                      4                     11
# 149                      4                     13
# 150                      4                     13
# 151                      4                     14
# 152                      4                     14
# 153                      3                      4
# 154                      3                      5
# 155                      3                      5
# 156                      3                      6
# 157                      3                      6
# 158                      3                      7
# 159                      3                      7
# 160                      3                      7
# 161                      3                      8
# 162                      3                      8
# 163                      6                     16
# 164                      6                     29
# 165                      5                      8
# 166                      5                      9
# 167                      5                      9
# 168                      5                      9
# 169                      5                      9
# 170                      5                     10
# 171                      5                     14
# 172                      4                      6
# 173                      4                      6
# 174                      4                      6
# 175                      4                      6
# 176                      4                      6
# 177                      4                      7
# 178                      4                      9
# 179                      4                      9
# 180                      4                      9
# 181                      4                     10
# 182                      4                     10
# 183                      6                     16
# 184                      6                     29
# 185                      5                      9
# 186                      5                      9
# 187                      5                     10
# 188                      5                     14
# 189                      4                      6
# 190                      4                      6
# 191                      4                      9
# 192                      4                      9
# 193                      4                      9
# 194                      4                     10
# 195                      4                     10
# 196                      4                     10
# 197                      4                     11
# 198                      4                     11
# 199                      4                     12
# 200                      4                     12
# 201                      4                     12
# 202                      4                     12
# 203                      5                      9
# 204                      5                      9
# 205                      4                      6
# 206                      4                      6
# 207                      4                     14
# 208                      4                     14
# 209                      4                     15
# 210                      4                     16
# 211                      3                      5
# 212                      3                      5
# 213                      3                      5
# 214                      3                      5
# 215                      3                      5
# 216                      3                      5
# 217                      3                      6
# 218                      3                      6
# 219                      3                      7
# 220                      3                      7
# 221                      3                      7
# 222                      3                      7
# 223                      6                     16
# 224                      6                     29
# 225                      5                      8
# 226                      5                      9
# 227                      5                      9
# 228                      5                      9
# 229                      5                      9
# 230                      5                     10
# 231                      5                     14
# 232                      5                     14
# 233                      4                      6
# 234                      4                      6
# 235                      4                      6
# 236                      4                      6
# 237                      4                      9
# 238                      4                      9
# 239                      4                      9
# 240                      4                      9
# 241                      4                     10
# 242                      4                     10

# %%
import pandas as pd

# Define the replacements dictionary
replacements = {
    'ÃƒÂ©': 'é',
    'â€“': '–',
    'Â': '',
    'Ã¢â‚¬â„¢': '’',
    'Ã¢â€žÂ¢': '™',
    'Ã§': 'ç',
    'Ã¼': 'ü',
    'Ã±': 'ñ',
    'Ã¶': 'ö',
    'â€œ': '“',
    'â€': '”',
    'â€˜': '‘',
    'â€™': '’',
    'â€': '†',
}

# Read the CSV file (assuming utf-8 encoding)
df = pd.read_csv('predicted_knowledge_graph_based.csv', encoding='utf-8')

# Specify the columns you want to fix
columns_to_fix = ['recipe', 'description']

# Apply the replacements to the specified columns
for column in columns_to_fix:
    for old, new in replacements.items():
        df[column] = df[column].str.replace(old, new, regex=False)

# Save the corrected CSV file
df.to_csv('corrected_predicted_knowledge_graph_based.csv', index=False)

print("Encoding issues fixed and saved to corrected_predicted_knowledge_graph_based.csv")
# Out:
# Encoding issues fixed and saved to corrected_predicted_knowledge_graph_based.csv
